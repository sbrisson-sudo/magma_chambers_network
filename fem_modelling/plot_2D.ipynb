# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from copy import deepcopy

# %%
data = pd.read_csv("./resultats_2D.csv")
data = data.values

data_b = pd.read_csv("./resultats_2D_finer.csv")
data_b = data_b.values

# %%
plt.plot(X, data[:,2])
plt.plot(X, data_b[:,2])

# %%
# Comparaison à formule de Moggi
# Paramètres donné dans FreeFEM
dp = 1e5
nu = 0.25
E = 25e9
G = E/(2*(1+nu ))
a = 2e3
zs = 20e3

# Calcul de la déformation en surface
s = dp*(1-nu)*a**3/G 

X = data[:,0]

R = np.sqrt(X**2+zs**2)
iR3 = 1/R**3
uz = s*zs*iR3

# %%
plt.plot(X, uz*10, label="Moggi")
plt.plot(X, data[:,2], label="Finite elements")
plt.legend()
plt.ylabel("Up displacement (m)")
# Out:
# Text(0, 0.5, 'Up displacement (m)')
